# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv("../input/credit-card-approval-prediction/application_record.csv")
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df_label = pd.read_csv("../input/credit-card-approval-prediction/credit_record.csv")
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]

# %%
df_label_clean
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# 5        5001712              -1       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [839345 rows x 3 columns]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
client_id = df_label_group.index
client_label = df_label_group['STATUS'].values

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_MOBIL', 'CODE_GENDER'], axis = 1)

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = [item for item in X_clien_id if item in client_id]

# %%
len(real_client_id)
# Out:
# 22737

# %%
y = np.array([client_label[np.where(client_id == item)][0] for item in real_client_id])

# %%
X_final = [X[np.where(X_clien_id == item), :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %%
3089/ (19648 + 3089)
# Out:
# 0.1358578528389849

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 4}
# 10CV accuracy : 53.40269786472318

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 52.02265372168284

# %%
import tensorflow as tf

# %%
tf.compat.v1.reset_default_graph() # Clear Model
np.random.seed(1) # Fix Randomness
tf.compat.v1.random.set_random_seed(1) # Fix Randomness

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(800, activation='relu', input_shape=(11,)),
  tf.keras.layers.Dense(400, activation='relu'),
  tf.keras.layers.Dense(200, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 800)               9600
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               320400
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               80200
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 435,401
# Trainable params: 435,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_acc = list()
val_acc = list()
for i in range(0,100):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# 20/20 [==============================] - 2s 45ms/step - loss: 0.6925 - accuracy: 0.5026 - val_loss: 0.6950 - val_accuracy: 0.5187
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6904 - accuracy: 0.5285 - val_loss: 0.6962 - val_accuracy: 0.5207
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6897 - accuracy: 0.5414 - val_loss: 0.6955 - val_accuracy: 0.5106
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6880 - accuracy: 0.5393 - val_loss: 0.6972 - val_accuracy: 0.5177
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6866 - accuracy: 0.5497 - val_loss: 0.6975 - val_accuracy: 0.5308
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6843 - accuracy: 0.5563 - val_loss: 0.6970 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6806 - accuracy: 0.5603 - val_loss: 0.6968 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6761 - accuracy: 0.5717 - val_loss: 0.6985 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6719 - accuracy: 0.5806 - val_loss: 0.6989 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6691 - accuracy: 0.5783 - val_loss: 0.6991 - val_accuracy: 0.5521
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6664 - accuracy: 0.5899 - val_loss: 0.7016 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6644 - accuracy: 0.5849 - val_loss: 0.7045 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6593 - accuracy: 0.5930 - val_loss: 0.7126 - val_accuracy: 0.5359
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6533 - accuracy: 0.5907 - val_loss: 0.7150 - val_accuracy: 0.5177
# 20/20 [==============================] - ETA: 0s - loss: 0.6538 - accuracy: 0.60 - 0s 16ms/step - loss: 0.6482 - accuracy: 0.6069 - val_loss: 0.7201 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6424 - accuracy: 0.6097 - val_loss: 0.7223 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6363 - accuracy: 0.6233 - val_loss: 0.7199 - val_accuracy: 0.5551
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6334 - accuracy: 0.6198 - val_loss: 0.7252 - val_accuracy: 0.5369
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6305 - accuracy: 0.6246 - val_loss: 0.7277 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6255 - accuracy: 0.6259 - val_loss: 0.7413 - val_accuracy: 0.5561
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6230 - accuracy: 0.6286 - val_loss: 0.7455 - val_accuracy: 0.5592
# 20/20 [==============================] - 0s 15ms/step - loss: 0.6215 - accuracy: 0.6289 - val_loss: 0.7855 - val_accuracy: 0.5541
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6320 - accuracy: 0.6216 - val_loss: 0.7616 - val_accuracy: 0.5349
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6237 - accuracy: 0.6173 - val_loss: 0.7619 - val_accuracy: 0.5308
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6170 - accuracy: 0.6312 - val_loss: 0.7577 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6072 - accuracy: 0.6456 - val_loss: 0.7671 - val_accuracy: 0.5329
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5982 - accuracy: 0.6458 - val_loss: 0.7852 - val_accuracy: 0.5319
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5956 - accuracy: 0.6496 - val_loss: 0.8094 - val_accuracy: 0.5440
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5973 - accuracy: 0.6524 - val_loss: 0.7970 - val_accuracy: 0.5501
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5987 - accuracy: 0.6506 - val_loss: 0.8063 - val_accuracy: 0.5490
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5983 - accuracy: 0.6476 - val_loss: 0.8060 - val_accuracy: 0.5228
# 20/20 [==============================] - 0s 17ms/step - loss: 0.5918 - accuracy: 0.6570 - val_loss: 0.7952 - val_accuracy: 0.5551
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5988 - accuracy: 0.6451 - val_loss: 0.7673 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5994 - accuracy: 0.6443 - val_loss: 0.7808 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5781 - accuracy: 0.6668 - val_loss: 0.7924 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5691 - accuracy: 0.6759 - val_loss: 0.8057 - val_accuracy: 0.5369
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5648 - accuracy: 0.6714 - val_loss: 0.7866 - val_accuracy: 0.5410
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5601 - accuracy: 0.6876 - val_loss: 0.7703 - val_accuracy: 0.5490
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5619 - accuracy: 0.6818 - val_loss: 0.7886 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5741 - accuracy: 0.6658 - val_loss: 0.7776 - val_accuracy: 0.5450
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5829 - accuracy: 0.6539 - val_loss: 0.7829 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5684 - accuracy: 0.6810 - val_loss: 0.8098 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5537 - accuracy: 0.6871 - val_loss: 0.8059 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5429 - accuracy: 0.6949 - val_loss: 0.8216 - val_accuracy: 0.5389
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5444 - accuracy: 0.6840 - val_loss: 0.8357 - val_accuracy: 0.5541
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5430 - accuracy: 0.6881 - val_loss: 0.8373 - val_accuracy: 0.5319
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5400 - accuracy: 0.6964 - val_loss: 0.8371 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5405 - accuracy: 0.6997 - val_loss: 0.8252 - val_accuracy: 0.5581
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5228 - accuracy: 0.7124 - val_loss: 0.8576 - val_accuracy: 0.5733
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5202 - accuracy: 0.7040 - val_loss: 0.8571 - val_accuracy: 0.5561
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5135 - accuracy: 0.7152 - val_loss: 0.8528 - val_accuracy: 0.5723
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5056 - accuracy: 0.7197 - val_loss: 0.8801 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4986 - accuracy: 0.7187 - val_loss: 0.9035 - val_accuracy: 0.5511
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4941 - accuracy: 0.7281 - val_loss: 0.9645 - val_accuracy: 0.5349
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4913 - accuracy: 0.7306 - val_loss: 0.9724 - val_accuracy: 0.5642
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4967 - accuracy: 0.7253 - val_loss: 0.9560 - val_accuracy: 0.5794
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4920 - accuracy: 0.7351 - val_loss: 0.9871 - val_accuracy: 0.5733
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4941 - accuracy: 0.7245 - val_loss: 1.0053 - val_accuracy: 0.5733
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4900 - accuracy: 0.7278 - val_loss: 0.9733 - val_accuracy: 0.5733
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4817 - accuracy: 0.7349 - val_loss: 0.9371 - val_accuracy: 0.5592
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4692 - accuracy: 0.7425 - val_loss: 0.9839 - val_accuracy: 0.5763
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4643 - accuracy: 0.7511 - val_loss: 1.0141 - val_accuracy: 0.5683
# 20/20 [==============================] - 0s 17ms/step - loss: 0.4753 - accuracy: 0.7389 - val_loss: 0.9945 - val_accuracy: 0.5743
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4707 - accuracy: 0.7420 - val_loss: 1.0264 - val_accuracy: 0.5511
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4497 - accuracy: 0.7561 - val_loss: 1.0742 - val_accuracy: 0.5672
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4450 - accuracy: 0.7587 - val_loss: 1.0862 - val_accuracy: 0.5693
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4467 - accuracy: 0.7564 - val_loss: 1.1275 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4459 - accuracy: 0.7546 - val_loss: 1.1490 - val_accuracy: 0.5612
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4498 - accuracy: 0.7561 - val_loss: 1.0920 - val_accuracy: 0.5541
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4487 - accuracy: 0.7569 - val_loss: 1.0802 - val_accuracy: 0.5561
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4413 - accuracy: 0.7571 - val_loss: 1.0630 - val_accuracy: 0.5521
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4457 - accuracy: 0.7589 - val_loss: 1.1051 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4484 - accuracy: 0.7528 - val_loss: 1.2423 - val_accuracy: 0.5683
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4544 - accuracy: 0.7620 - val_loss: 1.2124 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4548 - accuracy: 0.7599 - val_loss: 1.0747 - val_accuracy: 0.5925
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4598 - accuracy: 0.7518 - val_loss: 1.1057 - val_accuracy: 0.5976
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4456 - accuracy: 0.7620 - val_loss: 1.0948 - val_accuracy: 0.5804
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4381 - accuracy: 0.7700 - val_loss: 1.0489 - val_accuracy: 0.5814
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4481 - accuracy: 0.7604 - val_loss: 0.9986 - val_accuracy: 0.5844
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4539 - accuracy: 0.7544 - val_loss: 1.0481 - val_accuracy: 0.5784
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4470 - accuracy: 0.7496 - val_loss: 1.1306 - val_accuracy: 0.5794
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4324 - accuracy: 0.7683 - val_loss: 1.0854 - val_accuracy: 0.5824
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4033 - accuracy: 0.7923 - val_loss: 1.1028 - val_accuracy: 0.5814
# 20/20 [==============================] - 0s 19ms/step - loss: 0.3984 - accuracy: 0.7827 - val_loss: 1.1397 - val_accuracy: 0.5895
# 20/20 [==============================] - 0s 17ms/step - loss: 0.4039 - accuracy: 0.7835 - val_loss: 1.1579 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 17ms/step - loss: 0.4110 - accuracy: 0.7771 - val_loss: 1.2138 - val_accuracy: 0.6006
# 20/20 [==============================] - 0s 15ms/step - loss: 0.4052 - accuracy: 0.7837 - val_loss: 1.2305 - val_accuracy: 0.5905
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4009 - accuracy: 0.7908 - val_loss: 1.2167 - val_accuracy: 0.5915
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3968 - accuracy: 0.7890 - val_loss: 1.2227 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3807 - accuracy: 0.8002 - val_loss: 1.2104 - val_accuracy: 0.6006
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3801 - accuracy: 0.8024 - val_loss: 1.2314 - val_accuracy: 0.5945
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3783 - accuracy: 0.7984 - val_loss: 1.2806 - val_accuracy: 0.5935
# 20/20 [==============================] - 0s 15ms/step - loss: 0.3782 - accuracy: 0.7933 - val_loss: 1.3219 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 18ms/step - loss: 0.3851 - accuracy: 0.7941 - val_loss: 1.2914 - val_accuracy: 0.5844
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3777 - accuracy: 0.8004 - val_loss: 1.2976 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3759 - accuracy: 0.8042 - val_loss: 1.3157 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 15ms/step - loss: 0.3778 - accuracy: 0.7943 - val_loss: 1.3835 - val_accuracy: 0.5996
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3752 - accuracy: 0.8045 - val_loss: 1.2621 - val_accuracy: 0.5966
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3715 - accuracy: 0.7999 - val_loss: 1.3040 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3712 - accuracy: 0.7984 - val_loss: 1.2709 - val_accuracy: 0.5966

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = [i[0] for i in y_predict.tolist()]
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.6262135922330098

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
target_names = ['negative', 'positive']
C = confusion_matrix(y_test,y_predict) 
C = C / C.astype(np.float).sum(axis=1)*100
sns.heatmap(C, annot=True, fmt=".2f",cmap="GnBu",xticklabels=target_names, yticklabels=target_names)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()
